# %% [markdown]
# # 1. Intro to Python: plotting $P(T,V)$ surfaces

# %% [markdown]
# :::{attention} Section Goals:
# - Use Python to perform arithmetic calculations and make plots <br>
# - Plot, examine, interpret the ideal gas $P(V,T)$ state function <br>
# :::

# %% [markdown]
# ## 1.1: Print statements, text, and numbers

# %% [markdown]
# There are many libraries built for use in Python. Each library comes with a suite of functions and tools that you can reference and use, as long as you've loaded that library. Before we get to that though, let's start with some 'pre-built' functions that we can use without havign to load any libraries.
#
# The first program that many people learn to write is a "Hello, world!" program, which outputs the phrase _Hello, world!_To do so, we need the ```print()``` function. [`print()`](https://docs.python.org/3/library/functions.html#print) outputs whatever the object of the function is.
#
# In this case, the object is text data, stored as a [string](https://weisscharlesj.github.io/SciCompforChemists/notebooks/chapter_01/chap_01_notebook.html#strings). In Python, strings are indicated using either single (`'`) or double (`"`) quotations marks.
#
# Let's see it in action:

# %%
print('the world is waiting to be greeted')
# Out:
# the world is waiting to be greeted

# %% [markdown]
# ---
#
# **Your turn!**
#
# In the code cell below, use the print command to output the string: _Hello, world!_

# %%
#write your code here!

# %% [markdown]
# :::{tip} What was `#` for?
# :class: margin
#
# In Python, `#` denotes a comment. Comments can be used to annotate code to make it easier to read and understand. Python ignores everything on lines that begin with  `#`. If the line just read `write your code here`, an error would be raised--you can try it and see!
# :::

# %% [markdown]
# :::{admonition} **Solution** (click to expand)
# :class: dropdown
# :class: simple
#
# The code should read:
#
# ```python
# print("Hello, world!")
# ```
# :::

# %% [markdown]
# ---
#
# **Text data** is useful for inputting labels, descriptors, printing statements, etc. However, **numerical data** is also very useful.[^nums-useful] Numbers are stored as _integers_ (whole numbers) or _floats_ (decimals[^fp]).
#
#
# :::{hint} 🧐 **Consider:**
# :class: dropdown
# :class: simple
# :icon: false
# :open: true
# What do you think the Python output will be for each command below?
#
# A)  5 + 10 \
# B)  5.0 + 10.0
#
# Make a prediction, and test it in the code cell below.
#
# :::
#
# [^nums-useful]: [citation needed]
# [^fp]: "float" is short for "floating point number", referring to how the number and decimal position are handled.

# %%
#your code here

# %% [markdown]
# :::{admonition} Solution (click to expand)
# :class: dropdown
# :class: simple
#
# Running the code:
#
# ```Python
# # Addition
# print("A) ", 5 + 10)
# print("B) ", 5.0 + 10.0)
# ```
# should output:
#
# ```A) 15``` \
# ```B) 15.0```
#
# :::

# %% [markdown]
# **Pause & Consider:**
# 1. Is this aligned with your prediction? If so, how did you know? If not, does it make sense in retrospect?
# 2. Which value is an integer? Which is a float?
#
# :::{admonition} Solution (click to expand)
# :class: dropdown
# :class: simple
# Python output an integer (`15`) when two integers were added (`5+10`); it output a float (`15.0`) when two floats were added (`5.0+10.0`).
# :::
#
# :::{tip} A few notes about that code...
# :class: dropdown
# :class: simple
# - **Readability:** Space between values makes it easier to read (```5 + 10``` vs ```5+10```). Python ignores spaces _unless_ they are in a string.
#
# - **Function**: There are two items in each print command: one _string_ (acting as a label), and one calculation. Each item is separated by a comma--Python will print one and then the other, on the same line.
# :::

# %% [markdown]
# :::{hint} 🧐 **Consider:**
# :class: dropdown
# :class: simple
# :icon: false
# :open: true
#
# What do you think would happen if you added a _combination_ of integers and floats? Make a prediction, and then test it by printing one or more calculations in the code cell below.
# :::

# %%
#your code here

# %% [markdown]
# :::{admonition} Solution (click to expand)
# :class: dropdown
# :class: simple
#
# It will default to a float. For example:
#
# ``` Python
# print("test: ", 5 + 10.0)
# ```
#
# should output:
#
# ```test: 15.0```
# :::
