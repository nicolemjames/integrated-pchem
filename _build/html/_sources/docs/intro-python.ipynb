# %%
#cell metadata tagged: remove-cell 
from myst_nb import glue
from IPython.display import Markdown

# %% [markdown]
# (intro-pyth)=
# # Intro to Python (Hello Python)

# %% [markdown]
# :::{admonition} Section Goals:
# :class: attention
#
# Use Python to:
# - Declare and manipulate variables, strings, integers, and floats
# - Perform arithmetic calculations
# - Generate plots
# :::

# %% [markdown]
# (func-text-num)=
# ## Functions, text, and numbers

# %% [markdown]
# (print-strings)=
# ### Writing a program to output text
#
# The first program that many people learn to write is a "Hello, world!" program, which performs the function of outputting the phrase "Hello, world!"
#
#
# To do so, we need the `print()` {term}`function`. `print()` outputs whatever its object is. Similar to a mathematical function ($f(x)$), the function object is placed in the parentheses (`print(x)`).
#
# For a "Hello, world!" program, the object is text data stored as a {term}`string` data type. In Python, strings are indicated using either single (`'`) or double (`"`) quotations marks.
#
# Let's see it in action:

# %%
print('the world is waiting to be greeted')
# Out:
# the world is waiting to be greeted

# %% [markdown]
# :::{admonition} Side Note
# :class: hint margin simple
#
# `#` denotes a comment, for annotating code. Python ignores everything on a line after `#`. If the line just read `write your code here`, an error would be raised. You can try it and see!
# :::

# %% [markdown]
# ```{exercise} Greet the world
# :label: hello-world
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# In the code cell below, use the `print()` function to output the string: Hello, world!
#
# _Hint:_ To make the cells editable and executable, click the rocket symbol at the top of this page, click "live code", and wait for the progress window to read: "Launching from mybinder.org: ready"
# :::
# ::::
# ```

# %%
#write your code here!

# %%
#cell metadata tagged: remove-cell 

output="Hello, world!"

glue("hello-world-soln", output, display=False)

# %% [markdown]
# :::::{solution} hello-world
# :label: hello-world-soln
# :class: dropdown simple
#
# ::::{tab-set}
#
# :::{tab-item} (a)
# ```python
# print("Hello, world!")
# ```
# ```{glue:} hello-world-soln
# ```
# :::
# ::::
# :::::

# %% [markdown]
# (math-nums)=
# ### Floats, integers, and arithmetic
#
# Numerical data is also very useful.[^nums-useful] Numbers can be stored as an {term}`integer` or {term}`float` data type.  Python can also perform several arithmetic operations directly, much like a calculator. Common operators are summarized in {numref}`math-operators`.
#
# :::{admonition} Side Note
# :class: hint margin simple
# Python can also directly handle {term}`integer division` and {term}`modulus` operations.
# :::
#
# :::{table} Python syntax for common mathematical operators
# :name: math-operators
#
# | Operator | Operation |  Example | Equivalent to |
# | :---: | :---: | :---:  | :---:  |
# | + | Addition | `5 + 3`| $5+3$ |
# | - | Subtraction | `5 - 3`| $5-3$ |
# | * | Multiplication | `5 * 3`| $5\cdot3$ |
# | / | Division | `5 / 3 `| $\frac{5}{3}$ |
# | ** | Exponentiation | `5 ** 3 `| $5^3$ |
# :::
#
# Python follows standard order of operations: parentheses first, then exponents, then multiplication & division, then addition & subtraction.
#
# [^nums-useful]: [citation needed]

# %% [markdown]
# ```{exercise} Hello Math
# :label: hello-math
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# What do you think the Python output will be for each operation below? Make a prediction, then use the code cell below to test your prediction by performing the calculations and printing the outputs.
# 1.  5 + 10
# 2.  5.0 + 10.0
# :::
#
# :::{tab-item} (b)
# Make a prediction: What do you think would happen if you added a _combination_ of integers and floats?
#
# Test your prediction by printing one or more calculations in the code cell below.
# :::
#
# :::{tab-item} (c)
# In the code cells below, print:
# 1. 5 divided by 2
# 2. 10 raised to the 2nd power
# :::
#
# :::{tab-item} (d)
#
# Predict the output of each of the following lines, and then test your predictions by printing the outputs in the code cell below.
# 1. `print(2 * 3 - 1)`
# 2. `print(2 ** 3 - 1)`
# 3. `print(2 * (3 - 1))`
# :::
#
# ```

# %% [markdown]
# :::{admonition} Side Note
# :class: hint margin simple
# - Space between values can make reading code easier. Python ignores spaces _unless_ they are in a string.
#
#
# - Multiple objects can be included in one print command, separated by commas. Each will print sequentially, on the same line.
# :::

# %%
#your solution for (a) here

# %%
#your solution for (b) here

# %%
#your solution for (c) here

# %%
#your solution for (d) here

# %%
#cell metadata tagged: remove-cell

# (a) output
out_a = "1.  15\n2.  15.0" 
glue("hello-math-soln-a", Markdown(out_a), display=False)

# (b) output
out_b="test:  15.0"
glue("hello-math-soln-b", Markdown(out_b), display=False)

# (c) output
out_c = "1.  2.5\n2.  100"
glue("hello-math-soln-c", Markdown(out_c), display=False)

# (d) output
out_d = "1.  5\n2.  7\n3.  4"
glue("hello-math-soln-d", Markdown(out_d), display=False)

# %% [markdown]
# ::::::{solution} hello-math
# :label: hello-math-soln
# :class: dropdown simple
#
# :::::{tab-set}
#
# ::::{tab-item} (a)
#
# ```python
# print("1. ", 5 + 10)
# print("2. ", 5.0 + 10.0)
# ```
# ```{glue:} hello-math-soln-a
# ```
#
# Python outputs an integer (`15`) when two integers are added (`5 + 10`); it outputs a float (`15.0`) when two floats are added (`5.0 + 10.0`).
# ::::
#
# ::::{tab-item} (b)
# I predict it will default to a float. Let's see:
#
# ```python
# print("test: ", 5 + 10.0)
# ```
# ```{glue:} hello-math-soln-b
# ```
#
# Viola, it's a float! If it defaulted to an integer, information could be lost.
# ::::
#
# ::::{tab-item} (c)
# ```python
# print("1. ", 5/2)
# print("2. ", 10**2)
# ```
# ```{glue:} hello-math-soln-c
# ```
# ::::
#
# ::::{tab-item} (d)
# ```python
# print("1. ", 2 * 3 - 1)
# print("2. ", 2 ** 3 - 1)
# print("3. ", 2 * (3 - 1))
# ```
#
# ```{glue:} hello-math-soln-d
# ```
# Calculation 1 completes multiplication then subtraction:
#
# :::{math}
# 2 \cdot 3 - 1 \\
# 6 - 1 \\
# 5 \\
# :::
#
# Calculation 2 completes exponentiation then subtraction:
# :::{math}
# 2^3-1 \\
# 8-1 \\
# 7 \\
# :::
#
# Calculation 3 completes the parentheses then multiplication:
# :::{math}
# 2 \cdot (3-1) \\
# 2 \cdot 2 \\
# 4 \\
# :::
# ::::
# :::::
# ::::::

# %% [markdown]
# (var)=
# ## Variables

# %% [markdown]
# In programming, a {term}`variable` stores an object (string, integer, float, etc). Once a variable is assigned a value, it retains that value throughout a session until it is changed.
#
# Using variables instead of hardcoding in a specific value makes it easier to write, read, and update code. By assigning a value to a variable and then referring to the variable throughout, the value can be updated everywhere i the code at once by simply updating the definition.
#
# For example:
#
# :::{admonition} Side Note
# :class: hint margin simple
# Variables are case sensitive! They also cannot contain spaces or operators (`+`, `-`, etc).
# :::

# %%
#defining variables manually:
P = 1.0 #atm
R = 0.08206 #(L*atm)/(mol*K) 
T = 100 #K
n = 1.0 #mol

#defining a variable based on other variables:
V = n*R*T/P 

#display the calculated volume
print("Volume: ", V, " L")
# Out:
# Volume:  8.206  L

# %% [markdown]
# :::::{exercise} Hello Variables
# :label: hello-var
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# Following the structure in the example above, calculate and print:
#
# 1. Pressure ($P_\text{N2}$) of $n_\text{N2}=2.0$ mol
# 2. Pressure ($P_\text{O2}$) of $n_\text{O2}=0.5$ mol
#
# at the following conditions:
# - $V = 15 \text{ L}$
# - $T = 300 \text{ K}$
#
# _Hint:_ be sure to use different variables for different parameters, don't just overwrite them (e.g., `n_N2`, `n_O2` instead of just `n`).
# :::
#
# :::{tab-item} (b)
# Add on to your code to calculate the total pressure of the system.
#
# _Hint:_ Recall the law of partial pressures: $P_\text{total}=P_1+P_2+P_3+...$
# :::
#
# :::{tab-item} (c)
# Uh oh, things are heating up! Update your code to perform the calculations with $T=500 \text{ K}$
#
# _Hint:_ If you set up and used variables nicely, this should only require one single change!
# :::
# ::::
# :::::

# %%
#your answer here!

# %%
#cell metadata tagged: remove-cell

# (a)  
V = 15
R = 0.08206 
T_a = 300 
n_N2 = 2.0 
n_O2 = 0.5 

P_N2_a = n_N2 * R * T_a / V
P_O2_a = n_O2 * R * T_a / V

out_a = f"P_N2:  {P_N2_a}  atm\nP_O2:  {P_O2_a}  atm"
glue("hello-var-soln-a", Markdown(out_a), display=False)

# (b)
P_tot_a = P_N2_a + P_O2_a
out_b = f"P(N2):  {P_N2_a}  atm\nP(O2):  {P_O2_a}  atm\nP(total):  {P_tot_a}  atm"
glue("hello-var-soln-b", Markdown(out_b), display=False)

# (c)
T_c = 500 
P_N2_c = n_N2 * R * T_c / V
P_O2_c = n_O2 * R * T_c / V
P_tot_c = P_N2_c + P_O2_c

out_c = f"P(N2):  {P_N2_c}  atm\nP(O2):  {P_O2_c}  atm\nP(total):  {P_tot_c}  atm"
glue("hello-var-soln-c", Markdown(out_c), display=False)

# %% [markdown]
# :::::{solution} hello-var
# :label: hello-var-soln
# :class: dropdown simple
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# ```python
# #define values:
# V = 15 #L
# R = 0.08206 #(L*atm)/(mol*K)
# T = 300 #K
# n_N2 = 2.0 #mol
# n_O2 = 0.5 #mol
#
# #calculate P:
# P_N2 = n_N2*R*T/V
# P_O2 = n_O2*R*T/V
#
# print("P_N2: ", P_N2, " atm")
# print("P_O2: ", P_O2, " atm")
# ```
# ```{glue:} hello-var-soln-a
# ```
# :::
#
# :::{tab-item} (b)
#
# All we need to do is add the calculation $P_\text{total}=P_\text{O2}+P_\text{N2}$:
#
# ```python
# #define values:
# V = 15 #L
# R = 0.08206 #(L*atm)/(mol*K)
# T = 300 #K
# n_N2 = 2.0 #mol
# n_O2 = 0.5 #mol
#
# #calculate pressures:
# P_N2 = n_N2*R*T/V
# P_O2 = n_O2*R*T/V
#
# #calculate total pressure:
# P_tot=P_N2+P_O2
#
# print("P(N2): ", P_N2, " atm")
# print("P(O2): ", P_O2, " atm")
# print("P(total): ", P_tot, " atm")
# ```
# ```{glue:} hello-var-soln-b
# ```
# :::
#
# :::{tab-item} (c)
#
# Because we defined our system parameters as variables and referred to those variables in calculations, we can update the temperature for all calculations simply by updating the definition of `T`:
#
# ```python
# #define values:
# V = 15 #L
# R = 0.08206 #(L*atm)/(mol*K)
# T = 500 #K
# n_N2 = 2.0 #mol
# n_O2 = 0.5 #mol
#
# #calculate pressures:
# P_N2 = n_N2*R*T/V
# P_O2 = n_O2*R*T/V
#
# #calculate total pressure:
# P_tot=P_N2+P_O2
#
# print("P(N2): ", P_N2, " atm")
# print("P(O2): ", P_O2, " atm")
# print("P(total): ", P_tot, " atm")
# ```
# ```{glue:} hello-var-soln-c
# ```
# :::
# ::::
# :::::

# %% [markdown]
# (arr-list)=
# ## Arrays and lists

# %% [markdown]
# So far we have used {term}`scalar variable`s. As you might imagine, there are many situations where it is useful for a variable to represent a collection of values. This can be done using an {term}`array` or a {term}`list`. Similar to strings, floats, and integers, the list data-type is pre-installed in Python directly.
#
# Lists can de defined using square brackets (`[ ]`). For example:

# %%
this_is_a_string_list = ["list entry 1", "list entry 2", "list entry 3", "etc."]
this_is_a_float_list = [1.11, 1.12, 1.14, 1.15]
this_is_a_mixed_list = [1.11, 1.12, 1.14, 1.15, "etc."]

print("strings: ", this_is_a_string_list)
print("floats: ", this_is_a_float_list)
print("mixed: ", this_is_a_mixed_list)
# Out:
# strings:  ['list entry 1', 'list entry 2', 'list entry 3', 'etc.']
# floats:  [1.11, 1.12, 1.14, 1.15]
# mixed:  [1.11, 1.12, 1.14, 1.15, 'etc.']

# %% [markdown]
# In contrast, arrays are _not_ pre-installed. To use these, we need to load a {term}`coding library`. By loading a coding library, we load in definitions of functions and data types that we can use without having to define them ourselves.
#
# The [NumPy](https://numpy.org/)[^numpy] library is very useful for scientific calculations. Its array class enables mathematical calculations to be applied to the entire collection, can be used in plotting, etc. NumPy also contains a number of functions that can be used to generate an array; several of the more common ones are summarized in {numref}`numpy-arrays`
#
# :::{admonition} Side Note
# :class: hint margin simple
# Note that NumPy's `arange()` function includes the start value, but stops one shy of the stop value. The `linspace()` function includes both.
# :::
#
# :::{table} Common NumPy Functions that Generate Arrays
# :name: numpy-arrays
#
# | NumPy Function | Description | Example | Output |
# | :--- | :--- | :--- | :--- |
# | `array()` | Converts a Python list into a NumPy array | `np.array([0, 1, 2])` | `[0 1 2]` |
# | `arange()` | Given $x$, $y$, $z$, returns an array of $z$-spaced values from $x$ to $y$| `arange(0, 2, 1)` | `[0 1]` |
# | `linspace()` | Given $x$, $y$, $z$, returns an array of $z$ linearly-spaced values from $x$ to $y$  | `linspace(0, 2, 3)` | `[0 1 2]` |
# :::
#
# Consider the following:
#
# [^numpy]: pronounced "numb-pie", but if you want to say it like it rhymes with "lumpy" that's none of my business.

# %%
import numpy as np 
x = np.linspace(0, 20, 10)
print(x)
# Out:
# [ 0.          2.22222222  4.44444444  6.66666667  8.88888889 11.11111111
#  13.33333333 15.55555556 17.77777778 20.        ]

# %% [markdown]
# The first line loads the numpy library, and gives it the name `np`. When we want to call a function from a library, we need to tell Python which library it can find the function's definition in. As shown in the second line, we do that by prefixing the function name with `np.`.

# %% [markdown]
# ```{exercise} Hello Array
# :label: hello-shape
#
# ::::{tab-set}
#
# :::{tab-item} (a)
# In the code cell below, use NumPy's `linspace()` function to create a variable called `x_20` which ranges from  -4 to 4 and has 20 points. Print `x_20` so you can look at it.
# :::
#
# :::{tab-item} (b)
# You could manually count the points to confirm that `x_20` contains 20 objects. Or, you can take advantage of another NumPy function: [shape](https://numpy.org/devdocs/reference/generated/numpy.shape.html). `shape()` returns a {term}`tuple`: `(m,n)`, where _m_ is the number of rows in the array and _n_ is the number of columns. The syntax for this function is `np.shape(your_array).`
#
# Use `np.shape()` to verify that `x_20` is indeed 1 dimensional, with 20 entries.
# :::
#
# :::{tab-item} (c)
# Create a new variable, `y_20` defined as `y_20 = x_20+3`. Use the `np.shape()` function to confirm it has the same dimensions as `x_20`.
# :::
# ::::
# ```

# %%
#your answers here

# %%
#cell metadata tagged: remove-cell
import numpy as np 

#(a)
x_20 = np.linspace(-4, 4, 20)
# Use str() to perfectly mimic how print() formats a numpy array
out_a = str(x_20)
glue("hello-shape-soln-a", out_a, display=False)

#(b)
out_b1=str(np.shape(x_20))
glue("hello-shape-soln-b1", out_b1, display=False)

shipshape=np.shape(x_20)
out_b2=str(shipshape)
glue("hello-shape-soln-b2", out_b2, display=False)

#(c)
y_20 = x_20 + 3
out_c=str(np.shape(y_20))
glue("hello-shape-soln-c", out_c, display=False)

# %% [markdown]
# :::::{solution} hello-shape
# :label: hello-shape-soln
# :class: dropdown simple
#
# ::::{tab-set}
#
# :::{tab-item} (a)
# ```python
# x_20 = np.linspace(-4,4,20)
# print(x_20)
# ```
# ```{glue:} hello-shape-soln-a
# ```
# :::
#
# :::{tab-item} (b)
# This can be done by printing the shape function directly:
# ```python
# print(np.shape(x_20))
# ```
# ```{glue:} hello-shape-soln-b1
# ```
# or by assigning shape to a variable and printing that variable:
#
# ```python
# shipshape = np.shape(x_20)
# print(shipshape)
# ```
# ```{glue:} hello-shape-soln-b2
# ```
# :::
#
# :::{tab-item} (c)
# ```python
# y_20 = x_20 + 3
# print(np.shape(y_20))
# ```
# ```{glue:} hello-shape-soln-c
# ```
# :::
# ::::
# :::::

# %% [markdown]
# (plot)=
# ## Plotting

# %% [markdown]
# There are several libraries that facilitate visualizing data; a common one is [matplotlib](https://matplotlib.org/stable/users/index.html), which has a submodule called [pyplot](https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html). Let's see an example:
#
# :::{admonition} Side Note
# :class: hint margin simple
#
# Plots are very customizeable. For more info about plotting, see [Sci Comp for Chemists  §3.1](https://weisscharlesj.github.io/SciCompforChemists/notebooks/chapter_03/chap_03_notebook.html#plotting-basics)
# :::

# %%
#import the libraries we need
import numpy as np 
import matplotlib.pyplot as plt 

#get some stuff to plot

#let the total pressure be constant
P_tot = 1 #atm

#let pressure N2 vary from 0-1 atm
P_N2 = 1-np.linspace(0, 1, 10) #atm

#let pressure O2 vary relative to P_N2, to keep total P constant
P_O2 = P_tot - P_N2 #atm

#plot the stuff 
plt.figure(figsize=(3,3))
plt.plot(P_N2,P_O2,'o-')
plt.xlabel('N2 Pressue (atm)') 
plt.ylabel('O2 Pressure (atm)') 
plt.show()

# %% [markdown]
# Let's break this down:
#
# `plt.figure()`calls the `figure()` function from `matplotlib.pyplot`, which creates a figure window for the plot. We also defined the figure size to be 3 inches x 3 inches. Defining the figure size is optional, but the default starts off unnecessarily large.
#
#
# `plt.plot(P_N2, P_O2, 'o-')` plots into the figure window, with `P_N2`as the x-values and `P_O2` as the y-values. The `'o-'` input is optional; it tells `plot()` to display data point markers as circles (`o`) and display a line connecting each point (`-`). For other built-in marker options, see [the documentation](https://matplotlib.org/stable/api/markers_api.html).
#
#
# `plt.xlabel()`and `plt.ylabel()` display the inputted string as the x-axis or y-axis label, respectively.
#
# `plt.show()` displays the figure window and its contents. In many cases, Python will automatically display these even without this function, but including this function ensures it is displayed.
#
# ---
#
# If we want to plot multiple curves in the same window, we can do that by using `plt.plot()` multiple times:

# %%
import numpy as np 
import matplotlib.pyplot as plt 

P_tot = 1 #atm
P_N2 = 1-np.linspace(0, 1, 10) #atm
P_O2 = P_tot - P_N2 #atm
P_total=P_N2+P_O2 #atm -- to check it is indeed constant

plt.figure(figsize=(3,3))
plt.plot(P_N2,P_O2,'o-') #this is plots one curve
plt.plot(P_N2,P_total,'o-') #this plots another! 
plt.xlabel('N2 Pressue (atm)') 
plt.ylabel('Pressure (atm)') 
plt.show()

# %% [markdown]
# However, if we are doing that we should use a legend to label our curves! Matplotlib also has a function for that: [legend()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html). There's a couple ways to use `plt.legend()` to generate a label. One way is to create a list of the curve labels (list of strings), which are inputted to `plt.legend()` in the order the curves are plotted. For example:

# %%
import numpy as np 
import matplotlib.pyplot as plt 

P_tot = 1 #atm 
P_N2 = 1-np.linspace(0, 1, 10) #atm
P_O2 = P_tot - P_N2 #atm
P_total=P_N2+P_O2 #atm -- to check it is indeed constant

plt.figure(figsize=(3,3))
plt.plot(P_N2,P_O2,'o-')
plt.plot(P_N2,P_total,'o-')
plt.xlabel('N2 Pressue (atm)') 
plt.ylabel('Pressure (atm)') 

curve_names=['O2', 'Total'] 
plt.legend(curve_names)

plt.show()

# %% [markdown]
# Alternatively, the curve label can be defined within `plt.plot()`. When `plt.legend()` is called, it automatically refers to the the curve legend names as defined in plt.plot(). An advantage of this is you don't have to make sure you're manually keeping the order of the legend aligned with the order curves are plotted. For example:

# %%
import numpy as np 
import matplotlib.pyplot as plt 

P_tot = 1 #atm 
P_N2 = 1-np.linspace(0, 1, 10) #atm
P_O2 = P_tot - P_N2 #atm
P_total=P_N2+P_O2 #atm -- to check it is indeed constant

plt.figure(figsize=(3,3))
plt.plot(P_N2,P_O2,'o-', label='O2')
plt.plot(P_N2,P_total,'o-', label='Total')
plt.xlabel('N2 Pressue (atm)') 
plt.ylabel('Pressure (atm)') 

plt.legend()

plt.show()

# %% [markdown]
# ```{exercise} Just Plotting, no Scheming
# :label: hello-plots
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# Generate a figure that plots $y(x) = ax^3 + bx^2 + cx + d$ over the range $x = -5$ to $x = 5$, for the following values:
#
# $a = 3$ \
# $b = 1$ \
# $c = -3$ \
# $d = -5$
#
# Be sure to label your axes, and indicate your data points with markers!
# :::
#
# :::{tab-item} (b)
#
# Generate a figure and plot the following over the range $x = -5$ to $x = 5$:
# 1. $g(x) = 2x$
# 2. $h(x) = 2x^2$
# 3. $j(x) = 2x^3$
#
# Be sure to create a legend to label your curves!
#
# :::
# ::::
#
# ```

# %%
#your answer to (a) here!

# %%
#your answer to (b) here!

# %%
#cell metadata tagged: remove-cell

import numpy as np
import matplotlib.pyplot as plt

# (a)
a = 3
b = 1
c = -3
d = -5
x = np.linspace(-5, 5, 20)
y = a*x**3 + b*x**2 + c*x + d

fig_a = plt.figure(figsize=(3,3))
plt.plot(x, y, 'o-')
plt.xlabel('x')
plt.ylabel('y(x)')

glue("hello-plots-soln-a", fig_a, display=False)
plt.close(fig_a)

# (b)
g = 2*x
h = 2*x**2
j = 2*x**3

fig_b = plt.figure(figsize=(3,3))
plt.plot(x, g, 'o-', label="g(x)")
plt.plot(x, h, 'o-', label="h(x)")
plt.plot(x, j, 'o-', label="j(x)")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

glue("hello-plots-soln-b", fig_b, display=False)
plt.close(fig_b)

# %% [markdown]
# :::::{solution} hello-plots
# :label: hello-plots-soln
# :class: dropdown simple
#
# ::::{tab-set}
#
# :::{tab-item} (a)
#
# ```python
# #load libraries
# import numpy as np
# import matplotlib.pyplot as plt
#
# #define values
# a = 3
# b = 1
# c = -3
# d = -5
#
# #create array with x-values
# x=np.linspace(-5, 5, 20)
#
# #calculate y-values
# y= a*x**3 + b*x**2 + c*x + d
#
# #plot it
# plt.figure(figsize=(3,3))
# plt.plot(x,y,'o-')
# plt.xlabel('x')
# plt.ylabel('y(x)')
# plt.show()
# ```
# ```{glue:} hello-plots-soln-a
# ```
# :::
#
#
# :::{tab-item} (b)
#
# ```python
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# #create array with x-values
# x=np.linspace(-5, 5, 20)
#
# #calculate y-values for each function
# g = 2*x
# h = 2*x**2
# j = 2*x**3
#
# plt.figure(figsize=(3,3))
# plt.plot(x,g,'o-', label="g(x)")
# plt.plot(x,h,'o-', label="h(x)")
# plt.plot(x,j,'o-', label="j(x)")
# plt.xlabel('x')
# plt.ylabel('f(x)')
#
# plt.legend()
#
# plt.show()
# ```
# ```{glue:} hello-plots-soln-b
# ```
# :::
# ::::
# :::::

# %% [markdown]
# ## Glossary
#
# :::{glossary}
# string
#   A data type that stores characters (letters, punctuation, numbers). Numbers stored as a string will be treated as text (i.e., no math operations will work with those numbers).
#
# function
#   Functions can be called by name to perform a given task or series of tasks. A programming function can take an object. All functions must be defined, but several functions are predefined in Python directly; definitions for many others can be called collectively through calling a library package. The user can also define new or tailored functions.
#
# integer
#   A whole number (no decimal or remainder).
#
# float
#   A decimal number. Short for "floating point number", floats store both the number and position of the decimal.
#
# integer division
#   Returns the whole number result, dropping any remainder (decimal). For example: `5 \\ 3` would return `1`.
#
# modulus
#   modulus returns the remainder (decimal) only. For example: `5 % 3` would return `2`.
#
# variable
#   a storage location that "holds" a value. Essentially, a name that points to the object(s) or item(s) assigned to it.
#
# scalar variable
#   variables with just one assigned value
#
# array
#   a collection of objects of the same data type
#
# list
#   a collection of objects which may or may not be of the same data type
#
# tuple
#   a set of paired values, e.g.: (m,n)
#
# coding library
#   a package of pre-defined functions, objects, etc., that can be loaded into a program and used without having to manually include all definitions in the program itself.
# :::
